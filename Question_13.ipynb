# %%
import pandas as pd

# Load the dataset
orders_df = pd.read_csv('orders.csv')

# Count distinct users
distinct_users_count = orders_df['user_id'].nunique()

print(f"Number of distinct users who placed at least one order: {distinct_users_count}")
